# %% [markdown]
# Data Visualization using Matplotlib

# %% [markdown]
# Import matplolib

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Plot a line

# %%
a=[0,1,2,3,4,5,6]
b=[0,1,2,3,4,5,6]
sns.lineplot(x=a,y=b)
# Out:
# <Axes: >

# %%
a=[0,1,2,3,4,5,6]
b=[0,1,2,3,2,1,0]
sns.lineplot(x=a,y=b)
# Out:
# <Axes: >

# %% [markdown]
# To save plot in a file

# %%
a=[0,1,2,3,4,5,6]
b=[i*2 for i in a]
pic=sns.lineplot(x=a,y=b)
pic.figure.savefig("testImage.png",dpi=100)

# %% [markdown]
# Download Image to Local

# %%
from google.colab import files
files.download("testImage.png")

# %% [markdown]
# Plot a line with details

# %%
a=[5,2,7]
b=[2,16,4]

figs=sns.lineplot(x=a,y=b)
figs.set_title("Line Plot")
figs.set_xlabel("X-Axis")
figs.set_ylabel("Y-Axis")
# Out:
# Text(0, 0.5, 'Y-Axis')

# %% [markdown]
# Plot Multiple lines

# %%
x=[1,2,3,4,5]
y1=[20,40,60,80,90]
y2=[10,20,50,40,60]
y3=[70,60,90,40,20]
y4=[60,50,70,80,10]
figs=sns.lineplot(x=x,y=y1,label='Enfield')
sns.lineplot(x=x,y=y2,label='Honda')
sns.lineplot(x=x,y=y3,label='KTM')
sns.lineplot(x=x,y=y4,label='Bajaj')
figs.set_title("Bike Details in Line Plot")
figs.set_xlabel("Days")
figs.set_ylabel("Distance in Km")
# Out:
# Text(0, 0.5, 'Distance in Km')

# %% [markdown]
# Mini Project-3 Plot(Time Taken to convert text file to upper case)

# %%
x=[1,2,3,4,5]
y1=[50,60,70,80,90]
y2=[52,63,74,85,96]
y3=[54,66,78,99,120]
y4=[60,75,95,120,150]
y5=[65,85,105,135,185]
pics=sns.lineplot(x=x,y=y1,label='C',linewidth=2)
sns.lineplot(x=x,y=y2,label='C++',linewidth=1)
sns.lineplot(x=x,y=y3,label='Java',linewidth=3)
sns.lineplot(x=x,y=y4,label='Python',linewidth=2)
sns.lineplot(x=x,y=y5,label='R',linewidth=2)
pics.set_title("Programming Languages")
pics.set_xlabel("File size (GB)")
pics.set_ylabel("Time Taken (sec)")
# Out:
# Text(0, 0.5, 'Time Taken (sec)')

# %% [markdown]
# **Bar plot**

# %% [markdown]
# Plot a bar chart

# %%
x=['A','B','C','D']
y=[10,50,30,40]
sns.barplot(x=x,y=y,color="Brown")
# Out:
# <Axes: >

# %%
x=['A','B','C','D']
y=[10,50,30,40]
sns.barplot(x=y,y=x,color="Black")
# Out:
# <Axes: >

# %% [markdown]
# Plot a bar chart with details

# %%
import random as r
x=['A','B','C','D','E']
y=[r.randint(35,95) for i in range(5)]
pp= sns.barplot(x=x,y=y,color="blue")
pp.set_title("Student Performance in EST")
pp.set_xlabel("Student")
pp.set_ylabel("Marks in EST")
# Out:
# Text(0, 0.5, 'Marks in EST')

# %% [markdown]
# Horizontal Bar Plot(barh)

# %%
y=['A','B','C','D']
x=[10,50,30,40]
sns.barplot(x=x,y=y,color="Brown",orient='h')
# Out:
# <Axes: >

# %% [markdown]
# **Scatter Plot**

# %% [markdown]
# Simple Scatter Plot

# %%
import random as r
x=[5,2,9,6,4]
y=[10,5,8,4,2]
sns.scatterplot(x=x,y=y)
# Out:
# <Axes: >

# %%
x=[r.randint(0,100) for i in range(0,100)]
y=[r.randint(0,100) for i in range(0,100)]
sns.scatterplot(x=x,y=y)
# Out:
# <Axes: >

# %% [markdown]
# Scatter Plot in Detail

# %%
x=[35,20,29,40,57]
y=[100,50,40,80,200]
sct=sns.scatterplot(x=x,y=y)
sct.set_title("Age vs salary")
sct.set_xlabel("Age")
sct.set_ylabel("Salary * 1000")
# Out:
# Text(0, 0.5, 'Salary * 1000')

# %% [markdown]
# Multiple Scatter Plot

# %%
x=[35,20,29,40,57]
y1=[90,50,40,80,20]
y2=[10,50,30,40,70]
pp=sns.scatterplot(x=x,y=y1,label='A')
sns.scatterplot(x=x,y=y2,label='B',color='r')
pp.set_title("Age vs salary")
pp.set_xlabel("Age")
pp.set_ylabel("Salary * 1000")
plt.grid()

# %%
x=[35,20,29,40,57]
y1=[90,50,40,80,20]
x2=[44,22,23,34,42]
y2=[10,50,30,40,70]
pp=sns.scatterplot(x=x,y=y1,label='A')
sns.scatterplot(x=x2,y=y2,label='B',color='r')
pp.set_title("Age vs salary")
pp.set_xlabel("Age")
pp.set_ylabel("Salary * 1000")
plt.grid()

# %% [markdown]
# **Pie Plot**

# %% [markdown]
# Simple Pie Plot

# %%
import matplotlib.pyplot as plt
grades = 'A','B','C','D','E'
gradeCount=[90,50,140,40,20]
plt.pie(gradeCount, labels=grades, autopct='%1.3f%%')
plt.show()
print(type(grades))
# Out:
# <class 'tuple'>

# %% [markdown]
# Pie Plot - Explode-1

# %%
share = [3,4,2,1]
bikes = ['Enfield','Honda','Yahama','KTM']
plt.pie(share, labels=bikes,shadow=True, explode=(0.2,0,0,0), autopct='%1.2f%%')
plt.title('Bike Share')
plt.show()

# %%
share = [3,4,2,1]
bikes = ['Enfield','Honda','Yahama','KTM']
plt.pie(share, labels=bikes,shadow=True, explode=(0,0.1,0.2,0), autopct='%1.2f%%')
plt.title('Bike Share')
plt.show()

# %% [markdown]
# Working with user Dataset

# %%
import pandas as pd
df= pd.read_csv('/content/nbaDataset.csv')
df.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.head(10)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %% [markdown]
# Read sample data of Google Colab

# %%
import pandas as pd
df1= pd.read_csv('/content/sample_data/california_housing_test.csv')
df1.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
df1.tail()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# 2995      1258.0       607.0         1.1790            225000.0
# 2996      3496.0      1036.0         3.3906            237200.0
# 2997       693.0       220.0         2.2895             62000.0
# 2998        46.0        14.0         3.2708            162500.0
# 2999       753.0       260.0         8.5608            500001.0

# %% [markdown]
# Read data file from Google Drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
df1= pd.read_csv('/content/drive/MyDrive/nbaDataset/nbaDataset.csv')
df1.head()

# %% [markdown]
# Bar Graph

# %%
import seaborn as sns
x = df['Age']
y = df['Salary']
plt.figure(figsize=(10,10))
fig = sns.barplot(x = x, y = y, color = "purple",errorbar=None)
fig.set_xlabel('Age')
fig.set_ylabel('Salary(in millions)')
fig.set_title('Salary Vs Age')
# Out:
# Text(0.5, 1.0, 'Salary Vs Age')

# %% [markdown]
#  Horizontal bar graph

# %%
x = df['Age']
y = df['Salary']

fig2 = sns.barplot(x = y, y = x ,color = "green",orient = 'h')
fig2.set_xlabel('Salary')
fig2.set_ylabel('Age')
fig2.set_title('Salary Vs Age')
# Out:
# Text(0.5, 1.0, 'Salary Vs Age')

# %%
fig2 = sns.barplot(x = y, y = x ,color = "green",orient = 'h',errorbar=None)
fig2.set_xlabel('Salary')
fig2.set_ylabel('Age')
fig2.set_title('Salary Vs Age')
# Out:
# Text(0.5, 1.0, 'Salary Vs Age')

# %% [markdown]
# Scatter plot

# %%
x = df['Age']
y = df['Salary']

fig3 = sns.scatterplot(x = x,y = y, marker = "*")

fig3.set_xlabel('Age')
fig3.set_ylabel('Salary(in millions)')
fig3.set_title('Salary Vs Age')
# marker {'o','+','x','^','*','_'}
# Out:
# Text(0.5, 1.0, 'Salary Vs Age')

# %% [markdown]
# Plotting Mathematical Functions

# %% [markdown]
# Plot sine curve

# %%
import math as m

x=[m.pi*i for i in range(0,10)]
y=[m.sin(i) for i in x]

z=sns.lineplot(x=x,y=y)
z.set_title("Sine(pi) wave form")
# Out:
# Text(0.5, 1.0, 'Sine(pi) wave form')

# %% [markdown]
# Plot sine wave

# %%
import numpy as np

x=np.arange(0,4*m.pi,0.1)
y=np.sin(x)

z=sns.lineplot(x=x,y=y)
z.set_title("Sine wave form")
# Out:
# Text(0.5, 1.0, 'Sine wave form')

# %% [markdown]
# Plot Cos Wave

# %%
import numpy as np

x=np.arange(0,4*m.pi,0.1)
y=np.cos(x)

z=sns.lineplot(x=x,y=y)
z.set_title("Cos wave form")
# Out:
# Text(0.5, 1.0, 'Cos wave form')

# %% [markdown]
# **Subplot**

# %% [markdown]
#  Example-1

# %%
import numpy as np

x=np.arange(0,5*m.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)

z=sns.lineplot(x=x,y=y_cos,label="Cos")
z=sns.lineplot(x=x,y=y_sin,label="Sin")
z.set_title("Cos & Sin wave form")
# Out:
# Text(0.5, 1.0, 'Cos & Sin wave form')

# %% [markdown]
# Example-2

# %%
import numpy as np

x=np.arange(0,5*m.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)

plt.subplot(2,1,1)
z=sns.lineplot(x=x,y=y_cos)
z.set_title("Cos wave form")

plt.subplot(2,1,2)
z=sns.lineplot(x=x,y=y_sin)
z.set_title("Sin wave form")
# Out:
# Text(0.5, 1.0, 'Sin wave form')

# %% [markdown]
# **Box Plot**

# %% [markdown]
#  Data Generation

# %%
import numpy as np

data = [np.random.normal(0, std, 100) for std in range(1, 4)]

data
# Out:
# [array([ 0.07507366,  0.14955697,  1.61427326, -0.18752482,  0.95207659,
#         -0.15862518,  0.05160278,  0.06034621, -0.91280714, -0.34957604,
#          1.67906509, -0.53725183,  0.21652119,  0.03101961, -0.21030403,
#         -0.20207841,  1.0448499 , -1.56088661,  2.50114185,  0.88133165,
#          0.04604528, -1.97627042,  0.16202494, -0.06771128, -1.2826463 ,
#          0.03922367, -1.67037054,  2.11575182, -0.23204802,  0.3364918 ,
#         -0.0376113 ,  2.1613784 , -0.73158611,  1.58506275, -0.1499624 ,
#          1.00584332, -1.15378278,  2.99340526,  0.66135   , -1.69530743,
#         -0.44006568, -0.93269347,  0.07458923,  1.13056817, -2.65076154,
#         -0.0370479 ,  0.553604  , -0.34424026, -1.46523841,  0.08197381,
#         -0.61280061, -0.94507571, -1.94440537, -0.96797208, -0.94891571,
#         -0.4499207 , -1.05975728, -2.29563261,  1.09553612,  0.71627036,
#          0.22325389, -0.51750209, -0.2021328 , -1.06454652,  1.1155283 ,
# ...

# %% [markdown]
# The code data = [np.random.normal(0, std, 100) for std in range(1, 4)] creates a list of 3 NumPy arrays, each of which contains 100 random numbers drawn from a normal distribution with a mean of 0 and a standard deviation of 1, 2, or 3. The code first creates a range of values from 1 to 3, which will be used as the standard deviations for the normal distributions. Then, it uses a for loop to iterate over the range and generate a NumPy array of 100 random numbers for each standard deviation. Finally, it creates a list of the 3 NumPy arrays.

# %% [markdown]
# Box Plot - Vertical

# %%
sns.boxplot(data)
# Out:
# <Axes: >

# %% [markdown]
# Box Plot - Horizontal

# %%
sns.boxplot(data ,orient = 'h')
# Out:
# <Axes: >

# %% [markdown]
# **Plot Time Series**

# %% [markdown]
# Import libraries

# %%
import pandas as pd

# %% [markdown]
# Read Time Series Dataset

# %%
series=pd.read_csv('timeSeriesDataset.csv',header=0,index_col=0,parse_dates=True).squeeze('columns')
series.head()
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
# Name: Temp, dtype: float64

# %% [markdown]
# Minimum Daily Temperature Line Plot

# %%
series1 = pd.DataFrame(series)
sns.lineplot(series1)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
#  Minimum Daily Temperature Dot Plot

# %%
sns.scatterplot(series1)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Minimum Daily Temperature Yearly Line Plots

# %%
groups = series.groupby(pd.Grouper(freq='YE'))
years = pd.DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.plot(subplots=True, legend=False)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %% [markdown]
# for name, group in groups:: This line starts a loop that iterates over the grouped data. In each iteration, the loop assigns the name of the group (e.g., the specific year) to the name variable and the corresponding data for that group to the group variable.
#
# years[name.year] = group.values: This line adds a new column to the years DataFrame with the column name set as the year extracted from name. The values for this column are set to the values from the current group (group).

# %% [markdown]
# Minimum Daily Temperature Histogram Plot

# %%
sns.displot(series1)

# %% [markdown]
# Minimum Daily Temperature Density Plot

# %% [markdown]
# kdeplot (kernel density estimate)

# %%
sns.kdeplot(series1)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Minimum Daily Temperature Yearly Box and Whisker Plots

# %%
from pandas import DataFrame
from pandas import Grouper
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years.boxplot()
# Out:
# /tmp/ipython-input-125386936.py:3: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   groups = series.groupby(Grouper(freq='A'))
# <Axes: >

# %% [markdown]
# Minimum Daily Temperature Yearly Heat Map Plot

# %%
from pandas import Grouper
from matplotlib import pyplot
groups = series.groupby(Grouper(freq='A'))
years = DataFrame()
for name, group in groups:
    years[name.year] = group.values
years = years.T
pyplot.matshow(years, interpolation=None, aspect='auto')
# Out:
# /tmp/ipython-input-1700208053.py:3: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'YE' instead.
#   groups = series.groupby(Grouper(freq='A'))

# %% [markdown]
# Minimum Daily Temperature Lag Plot

# %%
from pandas.plotting import lag_plot
lag_plot(series)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# Minimum Daily Temperature Autocorrelation Plot

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>
